# %% [markdown]
# This project will be used for Data Science Capstone Project

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %%
from bs4 import BeautifulSoup

# %%
from pprint import pprint
postal_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]

# %% [markdown]
# We will now put the first row as the header by using postal_df.columns=header
# Then we will drop the first row since it is a header

# %%
#changing the column names
header=postal_df.iloc[0]
postal_df.columns=header
postal_df.drop(0,inplace=True)
postal_df
# Out:
# 0   Postcode           Borough  \
# 1        M1A      Not assigned
# 2        M2A      Not assigned
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 10       M8A      Not assigned
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 14       M2B      Not assigned
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 21       M7B      Not assigned
# 22       M8B      Not assigned
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ...

# %% [markdown]
# Checking how many unique values in postal_df. And it shows that there are 103 postcodes

# %%
len(postal_df['Postcode'].unique())
# Out:
# 180

# %% [markdown]
# We will now remove the data which have unassigned Borough using masking

# %%
#removing the unassigned boroughs
postal_df=postal_df[postal_df['Borough']!="Not assigned"]
postal_df.reset_index(inplace=True)
postal_df
# Out:
# 0    index Postcode           Borough  \
# 0        3      M3A        North York
# 1        4      M4A        North York
# 2        5      M5A  Downtown Toronto
# 3        6      M5A  Downtown Toronto
# 4        7      M6A        North York
# 5        8      M6A        North York
# 6        9      M7A      Queen's Park
# 7       11      M9A         Etobicoke
# 8       12      M1B       Scarborough
# 9       13      M1B       Scarborough
# 10      15      M3B        North York
# 11      16      M4B         East York
# 12      17      M4B         East York
# 13      18      M5B  Downtown Toronto
# 14      19      M5B  Downtown Toronto
# 15      20      M6B        North York
# 16      23      M9B         Etobicoke
# 17      24      M9B         Etobicoke
# 18      25      M9B         Etobicoke
# 19      26      M9B         Etobicoke
# 20      27      M9B         Etobicoke
# 21      28      M1C       Scarborough
# 22      29      M1C       Scarborough
# ...

# %% [markdown]
# Listing down each neighborhood in preparation for iteration

# %%
neighbourhood_list=postal_df['Neighbourhood'].tolist()
neighbourhood_list
# Out:
# ['Parkwoods',
#  'Victoria Village',
#  'Harbourfront',
#  'Regent Park',
#  'Lawrence Heights',
#  'Lawrence Manor',
#  'Not assigned',
#  'Islington Avenue',
#  'Rouge',
#  'Malvern',
#  'Don Mills North',
#  'Woodbine Gardens',
#  'Parkview Hill',
#  'Ryerson',
#  'Garden District',
#  'Glencairn',
#  'Cloverdale',
#  'Islington',
#  'Martin Grove',
#  'Princess Gardens',
#  'West Deane Park',
#  'Highland Creek',
#  'Rouge Hill',
#  'Port Union',
#  'Flemingdon Park',
#  'Don Mills South',
#  'Woodbine Heights',
#  'St. James Town',
#  'Humewood-Cedarvale',
#  'Bloordale Gardens',
#  'Eringate',
#  'Markland Wood',
#  'Old Burnhamthorpe',
#  'Guildwood',
#  'Morningside',
#  'West Hill',
#  'The Beaches',
#  'Berczy Park',
#  'Caledonia-Fairbanks',
#  'Woburn',
#  'Leaside',
#  'Central Bay Street',
#  'Christie',
#  'Cedarbrae',
#  'Hillcrest Village',
#  'Bathurst Manor',
#  'Downsview North',
#  'Wilson Heights',
#  'Thorncliffe Park',
#  'Adelaide',
#  'King',
#  'Richmond',
# ...

# %% [markdown]
# We will now change the unassigned Neighbourhood list by iterating each cell

# %%
#replacing Not assigned neighbourhood
replace_index=0
for name in neighbourhood_list:
    if(name=="Not assigned"):
        postal_df.iloc[replace_index, postal_df.columns.get_loc('Neighbourhood')]=postal_df.iloc[replace_index, postal_df.columns.get_loc('Borough')]
    replace_index=replace_index+1
# Out:
# C:\Users\Jervinne\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
postal_df.drop('index',axis=1,inplace=True)
postal_df
# Out:
# C:\Users\Jervinne\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# 0   Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 9        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 12       M4B         East York
# 13       M5B  Downtown Toronto
# 14       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# ...

# %% [markdown]
# Creating an empty DataFrame

# %%
final_df=pd.DataFrame(columns=['Postcode','Borough','Neighbourhood'])

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# Iterating each row in postal_df then if the row has a duplicate then it is added to the previous

# %%
#creating a copy of postal_df
unique_count=0
postal_df_copy=postal_df.copy()
prev_postal=""
while(len(postal_df_copy)>0):
    if(postal_df_copy.iloc[0, postal_df.columns.get_loc('Postcode')]==prev_postal):
        final_df.iloc[unique_count-1, final_df.columns.get_loc('Neighbourhood')]=final_df.iloc[unique_count-1, final_df.columns.get_loc('Neighbourhood')]+" ,"+postal_df_copy.iloc[0, postal_df_copy.columns.get_loc('Neighbourhood')]
        postal_df_copy.drop(0,inplace=True)
        postal_df_copy.reset_index(inplace=True)
        postal_df_copy.drop('index',axis=1,inplace=True)
    else:
        prev_postal=postal_df_copy.iloc[0, postal_df.columns.get_loc('Postcode')]
        #adding first row to the final_df
        unique_count=unique_count+1
        final_df=final_df.append(pd.Series([postal_df_copy.iloc[0, postal_df_copy.columns.get_loc('Postcode')],postal_df_copy.iloc[0, postal_df_copy.columns.get_loc('Borough')],postal_df_copy.iloc[0, postal_df_copy.columns.get_loc('Neighbourhood')]],index=['Postcode','Borough','Neighbourhood']),ignore_index=True)
        #deleting first row of postal_df_copy
        postal_df_copy.drop(postal_df_copy.index[0],inplace=True)
        postal_df_copy.reset_index(inplace=True)
        postal_df_copy.drop('index',axis=1,inplace=True)

# %%
final_df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# ...

# %% [markdown]
# Just like our assumption from before there are 103 postcodes

# %%
final_df.shape
# Out:
# (103, 3)

# %% [markdown]
# Getting latitude longitude of each postal code

# %%
location_csv= pd.read_csv("https://cocl.us/Geospatial_data")

# %%
location_csv

# %% [markdown]
# Sorting final_df by postcode to match the postcode values of location_csv

# %%
final_df=final_df.sort_values(by=['Postcode'])
final_df.reset_index(inplace=True)
final_df.drop('index',axis=1,inplace=True)

# %% [markdown]
# Adding the latitude and longitude to final_df

# %%
latitude_series=location_csv['Latitude']
longitude_series=location_csv['Longitude']
final_df.loc[:,'Latitude']=latitude_series
final_df.loc[:,'Longitude']=longitude_series
final_df

# %%
final_df

# %%
import json # library to handle JSON files


import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')

# %% [markdown]
# Looking for the unique values of Borough which has Toronto

# %%
final_df['Borough'].unique()

# %% [markdown]
# Using masking to get Toronto Boroughs

# %%
toronto_df=pd.DataFrame()

# %%
toronto_df=toronto_df.append(final_df[(final_df['Borough']=='East Toronto')],ignore_index=True)
toronto_df=toronto_df.append(final_df[(final_df['Borough']=='Central Toronto')],ignore_index=True)
toronto_df=toronto_df.append(final_df[(final_df['Borough']=='Downtown Toronto')],ignore_index=True)
toronto_df=toronto_df.append(final_df[(final_df['Borough']=='West Toronto')],ignore_index=True)
toronto_df

# %%
CLIENT_ID = 'B2KMI1TDU1PA4CTMSH2QSJRGADYSQUQXLWSTAW5CP2AAU13G' # your Foursquare ID
CLIENT_SECRET = 'XRRRWJDKHQ1PYRYNLVH1XMLRA2MJ3JRFQJYSZBI14BA2JS02' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
LIMIT = 100
def getNearbyVenues(postcodes,names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for code,name, lat, lng in zip(postcodes,names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            code,name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Postcode','Borough', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues= getNearbyVenues(postcodes=toronto_df['Postcode'],
                                names=toronto_df['Borough'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )

# %%
toronto_venues

# %% [markdown]
# Preparing for clustering by one hotting the Categories for each Postcode

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Postcode'] = toronto_venues['Postcode'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
toronto_onehot

# %% [markdown]
# Now we will find the mean of each category for each postcode

# %%
toronto_grouped=toronto_onehot.groupby('Postcode').mean().reset_index()
toronto_grouped

# %% [markdown]
# Displaying top 10 venues for each postcode

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Postcode']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
toronto_venues_sorted = pd.DataFrame(columns=columns)
toronto_venues_sorted['Postcode'] = toronto_grouped['Postcode']

for ind in np.arange(toronto_grouped.shape[0]):
    toronto_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

toronto_venues_sorted

# %% [markdown]
# Running k - means clustering and adding them to toronto_grouped

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Postcode', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

if('Cluster Labels' in toronto_venues_sorted.columns):
    toronto_venues_sorted['Cluster Labels']=kmeans.labels_
else:
    toronto_venues_sorted.insert(1, 'Cluster Labels', kmeans.labels_)

# %%
toronto_venues_sorted

# %%
cluster_group=toronto_venues_sorted.sort_values(by=['Cluster Labels'])

# %% [markdown]
# Based from the data below it seems Cluster 0 has common venue of coffee shop and/or cafe.
# Cluster 1 has Home Service.
# Cluster 2 has Park and Trail.
# Cluster 3 has Playground.
# Cluster 4 has Park but no trail.

# %%
cluster_group

# %% [markdown]
# We will now create a folium map

# %%
map_df=pd.DataFrame()
map_df['Cluster Labels']=toronto_venues_sorted['Cluster Labels']
map_df['Postcode']=toronto_venues_sorted['Postcode']
map_df['Latitude']=toronto_df['Latitude']
map_df['Longitude']= toronto_df['Longitude']
map_df.head()

# %% [markdown]
# getting the latitude of M5L since it seems that it is the center of cluster based on visual
# Then setting its latitude and longitude for folium

# %%
final_df[final_df['Postcode']=='M5L']

# %%
# create map
#latitude and longitude is set in M4E postcode
final_df
latitude= 43.648198
longitude= -79.379817
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(map_df['Latitude'], map_df['Longitude'], map_df['Postcode'], map_df['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster)+"\nLatitude: "+str(lat)+"\nLongitude: "+str(lon), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %% [markdown]
# Based from the map above it seems that cluster 1 which has coffee shop and/or cafe were quite trendy in Toronto
